# %%
import pandas as pd
import uuid

# %%
patients = pd.read_csv(r'D:\DEPI\DEPI final project\data sources\patients.csv')
patients.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 patients = pd.read_csv(r'D:\DEPI\DEPI final project\data sources\patients.csv')
#       2 patients.info()
#
# NameError: name 'pd' is not defined

# %%
patients.columns
# Out:
# Index(['Id', 'BIRTHDATE', 'DEATHDATE', 'SSN', 'DRIVERS', 'PASSPORT', 'PREFIX',
#        'FIRST', 'MIDDLE', 'LAST', 'SUFFIX', 'MAIDEN', 'MARITAL', 'RACE',
#        'ETHNICITY', 'GENDER', 'BIRTHPLACE', 'ADDRESS', 'CITY', 'STATE',
#        'COUNTY', 'FIPS', 'ZIP', 'LAT', 'LON', 'HEALTHCARE_EXPENSES',
#        'HEALTHCARE_COVERAGE', 'INCOME'],
#       dtype='str')

# %%
patients.DRIVERS.head(10)
# Out:
# 0          NaN
# 1    S99918355
# 2    S99914262
# 3          NaN
# 4    S99954548
# 5    S99966512
# 6    S99914459
# 7    S99912447
# 8    S99941379
# 9    S99997040
# Name: DRIVERS, dtype: str

# %%
patients_df = pd.DataFrame(patients, columns=["Id", "FIRST", "MIDDLE", "LAST", "BIRTHDATE", "GENDER", "RACE", "CITY", "STATE", "HEALTHCARE_COVERAGE"])

# %%
patients_df.head()
# Out:
#                                      Id      FIRST     MIDDLE         LAST  \
# 0  d54bbddf-1ab7-d6b1-1964-f12313ec0729     Sol312     Tom274  Ondricka197
# 1  2e6bf760-653f-e325-b20d-ebd85714d951   Jerri638  Lucinda68  Gislason620
# 2  0edbaaaf-ef5f-d58c-017e-004a706d388e     Son314        NaN    Dooley940
# 3  4f1a6def-6365-ffd7-6c93-e10ce3b386b7  Danita413        NaN    Schumm995
# 4  6531a1af-ef61-3596-3113-94649bff892c  Débora815  Carmen818   Jimínez732
#
#     BIRTHDATE GENDER   RACE         CITY          STATE  HEALTHCARE_COVERAGE
# 0  2025-07-09      M  black       Agawam  Massachusetts                 0.00
# 1  2008-08-23      F  black       Boston  Massachusetts                 0.00
# 2  2006-04-28      M  white  New Bedford  Massachusetts              3035.29
# 3  2012-07-06      F  white     Brockton  Massachusetts                 0.00
# 4  2001-12-22      F  white      Holyoke  Massachusetts            365078.60

# %%
patients_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 114614 entries, 0 to 114613
# Data columns (total 10 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Id                   114614 non-null  str
#  1   FIRST                114614 non-null  str
#  2   MIDDLE               91728 non-null   str
#  3   LAST                 114614 non-null  str
#  4   BIRTHDATE            114614 non-null  str
#  5   GENDER               114614 non-null  str
#  6   RACE                 114614 non-null  str
#  7   CITY                 114614 non-null  str
#  8   STATE                114614 non-null  str
#  9   HEALTHCARE_COVERAGE  114614 non-null  float64
# dtypes: float64(1), str(9)
# memory usage: 8.7 MB

# %%
patients_df.shape
# Out:
# (114614, 10)

# %%
patients_df.to_csv(r'D:\DEPI\DEPI final project\DATA_SOURCE_SQL\patients_df.csv',index=False)

# %%
patients_df.STATE.value_counts()
# Out:
# STATE
# Massachusetts    114614
# Name: count, dtype: int64

# %%
patients_df = patients_df.drop (columns="STATE")

# %%
patients_df.columns
# Out:
# Index(['Id', 'FIRST', 'MIDDLE', 'LAST', 'BIRTHDATE', 'GENDER', 'RACE', 'CITY',
#        'HEALTHCARE_COVERAGE'],
#       dtype='str')

# %%
patients_df.rename(
    columns={
        "Id": "patient_id",
        "MIDDLE": "middle_name",
        "FIRST": "first_name",
        "LAST": "last_name",
        "BIRTHDATE": "birth_date",
        "GENDER": "gender",
        "RACE": "race",
        "CITY": "city",
        "HEALTHCARE_COVERAGE": "insurance_type"
    },
    inplace=True
)

# %%
patients_df.columns = patients_df.columns.str.lower()

# %%
patients_df.head()
# Out:
#                              patient_id first_name middle_name    last_name  \
# 0  d54bbddf-1ab7-d6b1-1964-f12313ec0729     Sol312      Tom274  Ondricka197
# 1  2e6bf760-653f-e325-b20d-ebd85714d951   Jerri638   Lucinda68  Gislason620
# 2  0edbaaaf-ef5f-d58c-017e-004a706d388e     Son314         NaN    Dooley940
# 3  4f1a6def-6365-ffd7-6c93-e10ce3b386b7  Danita413         NaN    Schumm995
# 4  6531a1af-ef61-3596-3113-94649bff892c  Débora815   Carmen818   Jimínez732
#
#    birth_date gender   race         city  insurance_type
# 0  2025-07-09      M  black       Agawam            0.00
# 1  2008-08-23      F  black       Boston            0.00
# 2  2006-04-28      M  white  New Bedford         3035.29
# 3  2012-07-06      F  white     Brockton            0.00
# 4  2001-12-22      F  white      Holyoke       365078.60

# %%
patients_df.to_csv(r'D:\DEPI\DEPI final project\DATA_SOURCE_SQL\patients_df.csv',index=False)

# %%
medications = pd.read_csv(r'D:\DEPI\DEPI final project\data sources\medications.csv')
medications.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5668128 entries, 0 to 5668127
# Data columns (total 13 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   START              str
#  1   STOP               str
#  2   PATIENT            str
#  3   PAYER              str
#  4   ENCOUNTER          str
#  5   CODE               int64
#  6   DESCRIPTION        str
#  7   BASE_COST          float64
#  8   PAYER_COVERAGE     float64
#  9   DISPENSES          int64
#  10  TOTALCOST          float64
#  11  REASONCODE         float64
#  12  REASONDESCRIPTION  str
# dtypes: float64(4), int64(2), str(7)
# memory usage: 562.2 MB

# %%
# Out:
# Index(['START', 'STOP', 'PATIENT', 'PAYER', 'ENCOUNTER', 'CODE', 'DESCRIPTION',
#        'BASE_COST', 'PAYER_COVERAGE', 'DISPENSES', 'TOTALCOST', 'REASONCODE',
#        'REASONDESCRIPTION'],
#       dtype='str')

# %%
medications_df = pd.DataFrame(medications, columns=["PATIENT","ENCOUNTER","CODE","DESCRIPTION","START","STOP","TOTALCOST"])

# %%
medications_df.head()
# Out:
#                                 PATIENT                             ENCOUNTER  \
# 0  2e6bf760-653f-e325-b20d-ebd85714d951  2e6bf760-653f-e325-dcfc-a59741d48b02
# 1  2e6bf760-653f-e325-b20d-ebd85714d951  2e6bf760-653f-e325-434b-6a33c688f818
# 2  2e6bf760-653f-e325-b20d-ebd85714d951  2e6bf760-653f-e325-01be-253ea44acc2c
# 3  2e6bf760-653f-e325-b20d-ebd85714d951  2e6bf760-653f-e325-e107-e2a2d88f74d7
# 4  2e6bf760-653f-e325-b20d-ebd85714d951  2e6bf760-653f-e325-3669-44f38bf38ff5
#
#       CODE                                        DESCRIPTION  \
# 0   198405                       Ibuprofen 100 MG Oral Tablet
# 1  1535362              sodium fluoride 0.0272 MG/MG Oral Gel
# 2   834061          Penicillin V Potassium 250 MG Oral Tablet
# 3  1535362              sodium fluoride 0.0272 MG/MG Oral Gel
# 4   978950  {5 (dienogest 2 MG / estradiol valerate 2 MG O...
#
#                   START                  STOP  TOTALCOST
# 0  2016-12-17T18:31:16Z  2017-01-03T18:31:16Z      22.29
# ...

# %%
medications_df.columns
# Out:
# Index(['PATIENT', 'ENCOUNTER', 'CODE', 'DESCRIPTION', 'START', 'STOP',
#        'TOTALCOST'],
#       dtype='str')

# %%
uuids = [str(uuid.uuid4()) for _ in range(len(medications_df))]

medications_df.insert(0,"Medications_id",uuids)

medications_df.head()
# Out:
#                          Medications_id                               PATIENT  \
# 0  5e00a4ff-ae2b-4c53-a766-06dca9022240  2e6bf760-653f-e325-b20d-ebd85714d951
# 1  7d87ad06-181a-4ca3-96fb-b22e3519fbb1  2e6bf760-653f-e325-b20d-ebd85714d951
# 2  12734bda-3724-4079-a8e1-3dc0233023bc  2e6bf760-653f-e325-b20d-ebd85714d951
# 3  384c00d1-13dd-4c09-b560-f664aac2c2b1  2e6bf760-653f-e325-b20d-ebd85714d951
# 4  b3af2363-3985-4d6f-bdaa-e2ae79727da4  2e6bf760-653f-e325-b20d-ebd85714d951
#
#                               ENCOUNTER     CODE  \
# 0  2e6bf760-653f-e325-dcfc-a59741d48b02   198405
# 1  2e6bf760-653f-e325-434b-6a33c688f818  1535362
# 2  2e6bf760-653f-e325-01be-253ea44acc2c   834061
# 3  2e6bf760-653f-e325-e107-e2a2d88f74d7  1535362
# 4  2e6bf760-653f-e325-3669-44f38bf38ff5   978950
#
#                                          DESCRIPTION                 START  \
# 0                       Ibuprofen 100 MG Oral Tablet  2016-12-17T18:31:16Z
# ...

# %%
medications_df.columns
# Out:
# Index(['Medications_id', 'PATIENT', 'ENCOUNTER', 'CODE', 'DESCRIPTION',
#        'START', 'STOP', 'TOTALCOST'],
#       dtype='str')

# %%
medications_df.rename(
    columns= {
        "Medications_id": "medication_id",
        "PATIENT": "patient_id",
        "ENCOUNTER": "encounter_id",
        "CODE": "drug_code",
        "DESCRIPTION": "description",
        "START": "start_date",
        "STOP": "stop_date",
        "TOTALCOST": "cost"
	},
	inplace=True
)

# %%
medications_df.to_csv(r'D:\DEPI\DEPI final project\DATA_SOURCE_SQL\medications_df.csv',index= False)

# %%
conditions = pd.read_csv(r'D:\DEPI\DEPI final project\data sources\conditions.csv')
conditions.columns
# Out:
# Index(['START', 'STOP', 'PATIENT', 'ENCOUNTER', 'SYSTEM', 'CODE',
#        'DESCRIPTION'],
#       dtype='str')

# %%
uuids = [str(uuid.uuid4()) for _ in range(len(conditions))]

conditions_df = pd.DataFrame(conditions, columns = ["PATIENT","ENCOUNTER","CODE","DESCRIPTION","START","STOP"])
conditions_df.head()
# Out:
#                                 PATIENT                             ENCOUNTER  \
# 0  d54bbddf-1ab7-d6b1-1964-f12313ec0729  d54bbddf-1ab7-d6b1-a49a-24e20ddc7100
# 1  d54bbddf-1ab7-d6b1-1964-f12313ec0729  d54bbddf-1ab7-d6b1-09c5-f80dba9f2a9d
# 2  d54bbddf-1ab7-d6b1-1964-f12313ec0729  d54bbddf-1ab7-d6b1-7a19-8ddc742f961b
# 3  2e6bf760-653f-e325-b20d-ebd85714d951  2e6bf760-653f-e325-176c-fd561c3c03dd
# 4  2e6bf760-653f-e325-b20d-ebd85714d951  2e6bf760-653f-e325-1235-03978eff7331
#
#         CODE                        DESCRIPTION       START        STOP
# 0  314529007  Medication review due (situation)  2025-07-09  2025-07-09
# 1  314529007  Medication review due (situation)  2025-08-13  2025-10-15
# 2  314529007  Medication review due (situation)  2025-12-17         NaN
# 3  314529007  Medication review due (situation)  2015-08-15  2016-08-20
# 4  444814009         Viral sinusitis (disorder)  2016-05-19  2016-06-04

# %%
conditions_df.insert(0,"Condition_id",uuids)
conditions_df.columns
# Out:
# Index(['Condition_id', 'PATIENT', 'ENCOUNTER', 'CODE', 'DESCRIPTION', 'START',
#        'STOP'],
#       dtype='str')

# %%
conditions_df.rename(
    columns={
        "Condition_id": "condition_id",
        "PATIENT": "patient_id",
        "ENCOUNTER": "Encounter_id",
        "CODE": "icd10_code",
        "DESCRIPTION": "decription",
        "START": "onset_date",
        "STOP": "resolved_date"
	},
    inplace=True
)

# %%
conditions_df.to_csv(r'D:\DEPI\DEPI final project\DATA_SOURCE_SQL\conditions_df.csv',index= False)

# %%
encounters = pd.read_csv(r'D:\DEPI\DEPI final project\data sources\encounters.csv')

# %%
encounters.columns
# Out:
# Index(['Id', 'START', 'STOP', 'PATIENT', 'ORGANIZATION', 'PROVIDER', 'PAYER',
#        'ENCOUNTERCLASS', 'CODE', 'DESCRIPTION', 'BASE_ENCOUNTER_COST',
#        'TOTAL_CLAIM_COST', 'PAYER_COVERAGE', 'REASONCODE',
#        'REASONDESCRIPTION'],
#       dtype='str')

# %%
encounters_df = pd.DataFrame(encounters,columns = ["Id","PATIENT","PROVIDER","DESCRIPTION","START","STOP","TOTAL_CLAIM_COST"])
encounters_df.columns
# Out:
# Index(['Id', 'PATIENT', 'PROVIDER', 'DESCRIPTION', 'START', 'STOP',
#        'TOTAL_CLAIM_COST'],
#       dtype='str')

# %%
encounters_df.rename(
    columns={
        "Id": "encounter_id",
        "PATIENT": "patient_id",
        "PROVIDER": "provider_id",
        "DESCRIPTION": "encounter_type",
        "START": "start_time",
        "STOP": "end_time",
        "TOTAL_CLAIM_COST": "totel_cost"
    },
    inplace=True
)

# %%
encounters_df.to_csv(r'D:\DEPI\DEPI final project\DATA_SOURCE_SQL\Encounters_df.csv',index=False)

# %%
providers = pd.read_csv(r'D:\DEPI\DEPI final project\data sources\providers.csv')
providers.columns
# Out:
# Index(['Id', 'ORGANIZATION', 'NAME', 'GENDER', 'SPECIALITY', 'ADDRESS', 'CITY',
#        'STATE', 'ZIP', 'LAT', 'LON', 'ENCOUNTERS', 'PROCEDURES'],
#       dtype='str')

# %%
providers_df = pd.DataFrame(providers , columns= ["Id","NAME","SPECIALITY","ORGANIZATION","CITY"])
providers_df.columns
# Out:
# Index(['Id', 'NAME', 'SPECIALITY', 'ORGANIZATION', 'CITY'], dtype='str')

# %%
providers_df.rename(
    
	columns = {
		"Id": "provider_id",
        "NAME": "name",
        "SPECIALITY": "specialty",
        "ORGANIZATION": "organization_id",
        "CITY": "city"
	},
    inplace=True
)

# %%
providers_df.columns = providers_df.columns.str.lower()

# %%
providers_df.columns
# Out:
# Index(['provider_id', 'name', 'specialty', 'organization_id', 'city'], dtype='str')

# %%
providers_df.to_csv(r'D:\DEPI\DEPI final project\DATA_SOURCE_SQL\providers_df.csv',index=False)

# %%
organizations = pd.read_csv(r'D:\DEPI\DEPI final project\data sources\organizations.csv')
organizations.columns
# Out:
# Index(['Id', 'NAME', 'ADDRESS', 'CITY', 'STATE', 'ZIP', 'LAT', 'LON', 'PHONE',
#        'REVENUE', 'UTILIZATION'],
#       dtype='str')

# %%
organizations_df = pd.DataFrame(organizations,columns= ["Id","NAME","CITY","STATE"])
organizations_df.columns
# Out:
# Index(['Id', 'NAME', 'CITY', 'STATE'], dtype='str')

# %%
organizations_df.rename(
    columns={
        "Id": "id",
        "NAME": "name",
        "CITY": "city",
        "STATE": "state",
	},
	inplace=True
)

# %%
organizations_df.to_csv(r'D:\DEPI\DEPI final project\DATA_SOURCE_SQL\organization_df.csv',index=False)

# %%
claims = pd.read_json(r'D:\DEPI\DEPI final project\data sources\claims_Table.json',lines=True)

# %%
claims.columns
# Out:
# Index(['claim_id', 'patient_id', 'encounter_id', 'amount_billed',
#        'amount_paid', 'status', 'denial_reason', 'payer_id'],
#       dtype='str')

# %%
claims_df = pd.DataFrame(claims,columns=["claim_id","patient_id","encounter_id","payer_id","amount_billed","amount_paid","status"])

# %%
claims_df.rename(
    columns={
        "claim_id": "claim_id",
        "patient_id": "patient_id",
        "encounter_id": "encounter_id",
        "payer_id": "payer_id",
        "amount_billed": "amount_billed",
        "amount_paid": "amount_paid",
        "status": "Status"
    },
    inplace=True
)

# %%
claims_df.columns
# Out:
# Index(['claim_id', 'patient_id', 'encounter_id', 'payer_id', 'amount_billed',
#        'amount_paid', 'Status'],
#       dtype='str')

# %%
# claims_df.shape
claims_df = claims_df.drop_duplicates("claim_id")

# %%
claims_df.shape
# Out:
# (182622, 7)

# %%
claims_df.to_csv(r'D:\DEPI\DEPI final project\DATA_SOURCE_SQL\claims_df.csv',index=False)

# %%
payers = pd.read_json(r'D:\DEPI\DEPI final project\data sources\payer.json',lines=True)
payers.columns
# Out:
# Index(['payer_id', 'payer_name'], dtype='str')

# %%
payers.head(10)
# Out:
#    payer_id             payer_name
# 0         1            Brian Jones
# 1         2            Amy Collins
# 2         3         Christina Bell
# 3         4            Hunter Yang
# 4         5            Alan Miller
# 5         6       Christina Greene
# 6         7          Eric Phillips
# 7         8         Steven Kennedy
# 8         9  Mr. Richard Rodriguez
# 9        10            Kevin Evans

# %%
payers.to_csv(r'D:\DEPI\DEPI final project\DATA_SOURCE_SQL\payers.csv',index=False)
